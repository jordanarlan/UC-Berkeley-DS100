# %%
import pandas as pd
import numpy as np
import plotly.express as px

sales = pd.read_csv("/Users/jordan.arlan/Documents/DS100/Data/vgsales.csv")
sales
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
sales[["Year", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]].groupby("Year").agg(sum)
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1980.0     10.59      0.67      0.00         0.12         11.38
# 1981.0     33.40      1.96      0.00         0.32         35.77
# 1982.0     26.92      1.65      0.00         0.31         28.86
# 1983.0      7.76      0.80      8.10         0.14         16.79
# 1984.0     33.28      2.10     14.27         0.70         50.36
# 1985.0     33.73      4.74     14.56         0.92         53.94
# 1986.0     12.50      2.84     19.81         1.93         37.07
# 1987.0      8.46      1.41     11.63         0.20         21.74
# 1988.0     23.87      6.59     15.76         0.99         47.22
# 1989.0     45.15      8.44     18.36         1.50         73.45
# 1990.0     25.46      7.63     14.88         1.40         49.39
# 1991.0     12.76      3.95     14.78         0.74         32.23
# 1992.0     33.87     11.71     28.91         1.65         76.16
# 1993.0     15.12      4.65     25.33         0.89         45.98
# ...

# %%
sales_list = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]
sales[["Genre", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]].groupby("Genre").agg(sum)
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          877.83    525.00    159.95       187.38       1751.18
# Adventure       105.80     64.13     52.07        16.81        239.04
# Fighting        223.59    101.32     87.35        36.68        448.91
# Misc            410.24    215.98    107.76        75.32        809.96
# Platform        447.05    201.63    130.77        51.59        831.37
# Puzzle          123.78     50.78     57.31        12.55        244.95
# Racing          359.42    238.39     56.69        77.27        732.04
# Role-Playing    327.28    188.06    352.31        59.61        927.37
# Shooter         582.60    313.27     38.28       102.69       1037.37
# Simulation      183.31    113.38     63.70        31.52        392.20
# Sports          683.35    376.85    135.37       134.97       1330.93
# Strategy         68.70     45.34     49.46        11.36        175.12

# %%
sales.sort_values("Global_Sales", ascending=False).groupby("Platform").agg(lambda x : x.iloc[0]).sort_values("Year")
# Out:
#            Rank                                    Name    Year         Genre  \
# Platform
# 2600         90                                 Pac-Man  1982.0        Puzzle
# NES           2                       Super Mario Bros.  1985.0      Platform
# SNES         19                       Super Mario World  1990.0      Platform
# GEN         144                    Sonic the Hedgehog 2  1992.0      Platform
# GG        13527            Sonic the Hedgehog 2 (8-bit)  1992.0      Platform
# SCD        1263                                Sonic CD  1993.0      Platform
# NG         6683                      Samurai Shodown II  1994.0      Fighting
# 3DO       12637                             Policenauts  1995.0     Adventure
# TG16       9225                              Doukyuusei  1995.0     Adventure
# SAT         890                        Virtua Fighter 2  1995.0      Fighting
# GB            5                Pokemon Red/Pokemon Blue  1996.0  Role-Playing
# ...

# %%
sales.groupby("Year").size()
# Out:
# Year
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     349
# 2001.0     482
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2005.0     941
# 2006.0    1008
# 2007.0    1202
# 2008.0    1428
# 2009.0    1431
# 2010.0    1259
# 2011.0    1139
# 2012.0     657
# 2013.0     546
# 2014.0     582
# 2015.0     614
# 2016.0     344
# 2017.0       3
# 2020.0       1
# dtype: int64

# %%
sales.groupby("Year").filter(lambda sf: sf["Global_Sales"].max() < 5)
# Out:
#         Rank                                               Name Platform  \
# 221      222                                            FIFA 17      PS4
# 231      232            The Legend of Zelda: A Link to the Past     SNES
# 239      240                                           Pitfall!     2600
# 251      252                    Zelda II: The Adventure of Link      NES
# 254      255                                 Sonic the Hedgehog      GEN
# ...      ...                                                ...      ...
# 16562  16565                                       Mighty No. 9     XOne
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16576  16579                                  Rugby Challenge 3     XOne
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Find the total global sales each year for each platform
sales.groupby(["Year", "Platform"])[sales_list].agg(sum)
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year   Platform
# 1980.0 2600         10.59      0.67      0.00         0.12         11.38
# 1981.0 2600         33.40      1.96      0.00         0.32         35.77
# 1982.0 2600         26.92      1.65      0.00         0.31         28.86
# 1983.0 2600          5.44      0.34      0.00         0.06          5.83
#        NES           2.32      0.46      8.10         0.08         10.96
# ...                   ...       ...       ...          ...           ...
# 2016.0 X360          0.36      0.40      0.00         0.07          0.83
#        XOne          6.69      4.63      0.01         1.05         12.37
# 2017.0 PS4           0.00      0.00      0.03         0.00          0.03
#        PSV           0.00      0.00      0.02         0.00          0.02
# 2020.0 DS            0.27      0.00      0.00         0.02          0.29
#
# [241 rows x 5 columns]

# %%
# The `pivot_table` method is used to generate a Pandas pivot table
import numpy as np
sales.pivot_table(index = "Year", columns = "Platform", values = "Global_Sales", aggfunc = np.sum)
# Out:
# Platform   2600   3DO    3DS    DC      DS     GB    GBA     GC    GEN    GG  \
# Year
# 1980.0    11.38   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1981.0    35.77   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1982.0    28.86   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1983.0     5.83   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1984.0     0.27   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1985.0     0.45   NaN    NaN   NaN    0.02    NaN    NaN    NaN    NaN   NaN
# 1986.0     0.66   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1987.0     1.98   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 1988.0     0.75   NaN    NaN   NaN     NaN   1.43    NaN    NaN    NaN   NaN
# 1989.0     0.62   NaN    NaN   NaN     NaN  64.98    NaN    NaN    NaN   NaN
# 1990.0      NaN   NaN    NaN   NaN     NaN   4.89    NaN    NaN   2.60   NaN
# ...

# %%
l = sales[["Name","Platform", "Global_Sales"]]
r = sales[["Name", "Platform" ,"Other_Sales"]]

# %%
m = pd.merge(left = l, right = r, left_on = ["Name","Platform"], right_on = ["Name","Platform"])
m
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue       GB
# ...                                                 ...      ...
# 16603                Woody Woodpecker in Crazy Castle 5      GBA
# 16604                     Men in Black II: Alien Escape       GC
# 16605  SCORE International Baja 1000: The Official Game      PS2
# 16606                                        Know How 2       DS
# 16607                                  Spirits & Spells      GBA
#
#        Global_Sales  Other_Sales
# 0             82.74         8.46
# 1             40.24         0.77
# 2             35.82         3.31
# 3             33.00         2.96
# ...
